# %%
from jigsaw import Piece

# %%
piece = Piece(1)
piece.display_back()

# %%
piece.display_back()

# %%
piece = Piece(0)
num = 2
piece.edges[num].plot()
piece = Piece(5)
num = 0
piece.edges[num].plot()

# %%
piece_0_2 = Piece(0)
piece_5_0 = Piece(5)

edge_0_2 = piece_0_2.edges[2]
edge_5_0 = piece_5_0.edges[0]

# %%
edge_0_2.straighten_contour
# Out:
# array([[ 2.22020269e+02,  0.00000000e+00],
#        [ 2.19020543e+02, -4.05368394e-02],
#        [ 2.15980280e+02,  2.91865244e+00],
#        [ 2.14980372e+02,  2.90514016e+00],
#        [ 2.13966951e+02,  3.89153658e+00],
#        [ 2.05967681e+02,  3.78343834e+00],
#        [ 2.04981285e+02,  2.77001736e+00],
#        [ 2.02981467e+02,  2.74299280e+00],
#        [ 2.00954625e+02,  4.71578565e+00],
#        [ 1.80956451e+02,  4.44554005e+00],
#        [ 1.79943030e+02,  5.43193648e+00],
#        [ 1.74943487e+02,  5.36437508e+00],
#        [ 1.72916645e+02,  7.33716793e+00],
#        [ 1.50918653e+02,  7.03989777e+00],
#        [ 1.49932257e+02,  6.02647679e+00],
#        [ 1.39933170e+02,  5.89135399e+00],
#        [ 1.38919749e+02,  6.87775042e+00],
#        [ 1.32920296e+02,  6.79667674e+00],
#        [ 1.31906875e+02,  7.78307316e+00],
#        [ 1.30906967e+02,  7.76956088e+00],
#        [ 1.29893546e+02,  8.75595731e+00],
#        [ 1.28893637e+02,  8.74244503e+00],
#        [ 1.27880216e+02,  9.72884145e+00],
#        [ 1.26880307e+02,  9.71532917e+00],
#        [ 1.25866886e+02,  1.07017256e+01],
#        [ 1.24866978e+02,  1.06882133e+01],
#        [ 1.19799873e+02,  1.56201954e+01],
#        [ 1.19691774e+02,  2.36194651e+01],
#        [ 1.20678171e+02,  2.46328861e+01],
#        [ 1.20651146e+02,  2.66327035e+01],
#        [ 1.21637543e+02,  2.76461245e+01],
#        [ 1.21610518e+02,  2.96459419e+01],
#        [ 1.22596915e+02,  3.06593629e+01],
#        [ 1.22583402e+02,  3.16592716e+01],
#        [ 1.23569799e+02,  3.26726925e+01],
#        [ 1.23556286e+02,  3.36726013e+01],
#        [ 1.25529079e+02,  3.56994432e+01],
#        [ 1.25502055e+02,  3.76992606e+01],
#        [ 1.26488451e+02,  3.87126816e+01],
#        [ 1.26474939e+02,  3.97125903e+01],
#        [ 1.27461335e+02,  4.07260113e+01],
#        [ 1.27447823e+02,  4.17259200e+01],
#        [ 1.28434219e+02,  4.27393410e+01],
#        [ 1.28420707e+02,  4.37392497e+01],
#        [ 1.29407104e+02,  4.47526707e+01],
#        [ 1.29326030e+02,  5.07521229e+01],
#        [ 1.28312609e+02,  5.17385193e+01],
#        [ 1.28258560e+02,  5.57381542e+01],
#        [ 1.27258651e+02,  5.57246419e+01],
#        [ 1.25231809e+02,  5.76974347e+01],
#        [ 1.25204785e+02,  5.96972521e+01],
#        [ 1.24218388e+02,  5.86838312e+01],
#        [ 1.23204967e+02,  5.96702276e+01],
#        [ 1.23191455e+02,  6.06701363e+01],
#        [ 1.22178034e+02,  6.16565327e+01],
# Out:
# (array([220.02044678, 213.40841295, 207.53292589, 200.26054425,
#         193.38870089, 186.11632066, 178.84394042, 171.97209768,
#         164.69971526, 157.42733283, 150.98329779, 143.7890077 ,
#         136.83907669, 129.56669748, 123.61999998, 118.81198741,
#         115.79950712, 117.7114518 , 120.1938813 , 123.13300274,
#         122.46430764, 123.37069902, 120.75402217, 115.27123711,
#         109.76263197, 103.41725791,  96.52229886,  89.41330971,
#          82.56874335,  76.46549984,  71.25227486,  68.33478096,
#          67.42839195,  70.20961417,  74.01598544,  77.11930866,
#          78.76192068,  78.61168957,  73.37225467,  66.95549921,
#          60.36993994,  53.69417439,  46.42179339,  39.14941238,
#          32.19424531,  25.00519214,  18.16062263,  11.28878252,
#           7.27238069,   0.        ]),
#  array([-1.31006317e-14,  3.02575355e-01,  8.29808497e-01,  7.30639637e-01,
#          1.63702576e+00,  1.53785688e+00,  1.43868800e+00,  2.34507412e+00,
#          2.24590519e+00,  2.14673627e+00,  2.05886307e+00,  2.15574582e+00,
#          2.86608048e+00,  2.76691162e+00,  5.99586299e+00,  1.06209999e+01,
#          1.54934637e+01,  2.19647613e+01,  2.82088167e+01,  3.42709583e+01,
#          4.01224895e+01,  4.69943288e+01,  5.31834761e+01,  5.75770871e+01,
#          6.19058606e+01,  6.41339458e+01,  6.37039474e+01,  6.32250367e+01,
#          6.21316098e+01,  5.93152911e+01,  5.53240889e+01,  4.92533329e+01,
#          4.23814927e+01,  3.62631502e+01,  3.05859115e+01,  2.46061657e+01,
#          1.79978989e+01,  1.08248617e+01,  6.00099584e+00,  3.91330841e+00,
#          2.21792628e+00,  7.32193257e-01,  6.33024435e-01,  5.33855613e-01,
#          1.23104877e+00,  1.34107286e+00,  2.47644842e-01,  1.15403087e+00,
#          9.91688309e-02,  0.00000000e+00]))

# %%
edge_0_2.dissimilarity(edge_5_0, plot=True)
# Out:
# np.float64(5.474629971241544)

# %%
import numpy as np
from itertools import product

c1 = 0.5  # Coeficiente para la diferencia de longitudes
n_samples = 50  # Número de muestras para el remuestreo

test_edge = Piece(8).edges[3]

def disimilarity_tests(i_piece, i_edge, c1=c1, n_samples=n_samples):
    piece = Piece(i_piece)
    edge = piece.edges[i_edge]
    return test_edge.dissimilarity(edge, c1=c1, n_samples=n_samples, plot=False)

# Generar todas las combinaciones (pieza, arista)
piece_edge_combinations = list(product(range(25), range(4)))

# Ordenar por dissimilarity (de menor a mayor)
piece_edge_combinations_sorted = sorted(
    piece_edge_combinations, 
    key=lambda x: disimilarity_tests(x[0], x[1], c1=c1, n_samples=n_samples)
)

for i_piece, i_edge in piece_edge_combinations_sorted:
    disim = disimilarity_tests(i_piece, i_edge, c1=c1, n_samples=n_samples)
    print(f"Piece {i_piece} Edge {i_edge} -> Dissimilarity: {disim}")
# Out:
# Piece 9 Edge 1 -> Dissimilarity: 4.345923483175545
# Piece 24 Edge 0 -> Dissimilarity: 6.262034852830051
# Piece 21 Edge 0 -> Dissimilarity: 7.9121636123862285
# Piece 11 Edge 0 -> Dissimilarity: 10.257633149036014
# Piece 23 Edge 2 -> Dissimilarity: 10.391811075319813
# Piece 21 Edge 3 -> Dissimilarity: 12.091210513029504
# Piece 23 Edge 0 -> Dissimilarity: 12.310156161396861
# Piece 7 Edge 0 -> Dissimilarity: 12.769003333725808
# Piece 11 Edge 2 -> Dissimilarity: 13.053010439810425
# Piece 1 Edge 0 -> Dissimilarity: 13.343251465177623
# Piece 1 Edge 2 -> Dissimilarity: 15.05043170345369
# Piece 0 Edge 1 -> Dissimilarity: 15.404422340225706
# Piece 10 Edge 3 -> Dissimilarity: 15.529720549184669
# Piece 24 Edge 1 -> Dissimilarity: 16.21332278790797
# Piece 4 Edge 0 -> Dissimilarity: 16.88332221173752
# Piece 7 Edge 2 -> Dissimilarity: 17.01385865832124
# Piece 2 Edge 0 -> Dissimilarity: 17.33823957725857
# Piece 6 Edge 3 -> Dissimilarity: 18.671039203630414
# Piece 0 Edge 3 -> Dissimilarity: 19.963426814544217
# Piece 9 Edge 3 -> Dissimilarity: 21.780695422845422
# Piece 8 Edge 1 -> Dissimilarity: 21.7865786061893
# Piece 21 Edge 2 -> Dissimilarity: 21.799491851341465
# Piece 4 Edge 2 -> Dissimilarity: 21.91388812510348
# Piece 19 Edge 1 -> Dissimilarity: 22.2798198872989
# Piece 20 Edge 3 -> Dissimilarity: 23.46631436678342
# Piece 24 Edge 2 -> Dissimilarity: 23.710702558176756
# Piece 14 Edge 0 -> Dissimilarity: 25.621668355795393
# Piece 12 Edge 1 -> Dissimilarity: 26.479367149906516
# Piece 6 Edge 1 -> Dissimilarity: 27.35765333163425
# Piece 22 Edge 3 -> Dissimilarity: 27.83536777787644
# Piece 13 Edge 0 -> Dissimilarity: 31.735431293707308
# Piece 18 Edge 1 -> Dissimilarity: 32.71649090626774
# Piece 18 Edge 0 -> Dissimilarity: 33.89835210199362
# Piece 14 Edge 2 -> Dissimilarity: 35.56938041193254
# Piece 2 Edge 1 -> Dissimilarity: 35.6487698936107
# Piece 24 Edge 3 -> Dissimilarity: 36.46605651622461
# Piece 17 Edge 0 -> Dissimilarity: 40.49404373184467
# Piece 8 Edge 0 -> Dissimilarity: 41.45591475469011
# Piece 17 Edge 2 -> Dissimilarity: 42.853171057486776
# Piece 5 Edge 0 -> Dissimilarity: 44.572247635825335
# Piece 19 Edge 3 -> Dissimilarity: 45.090482187897166
# Piece 16 Edge 3 -> Dissimilarity: 45.26260422980498
# Piece 3 Edge 3 -> Dissimilarity: 45.877916215403374
# Piece 3 Edge 1 -> Dissimilarity: 47.84053760835191
# Piece 12 Edge 3 -> Dissimilarity: 56.18599913915702
# Piece 20 Edge 0 -> Dissimilarity: 57.09858147646226
# Piece 5 Edge 2 -> Dissimilarity: 61.261453257189764
# Piece 13 Edge 3 -> Dissimilarity: 63.331092916901035
# Piece 16 Edge 1 -> Dissimilarity: 66.39770658518961
# Piece 15 Edge 1 -> Dissimilarity: 77.89035796598301
# Piece 10 Edge 2 -> Dissimilarity: 78.23105001404161
# Piece 0 Edge 0 -> Dissimilarity: inf
# Piece 0 Edge 2 -> Dissimilarity: inf
# Piece 1 Edge 1 -> Dissimilarity: inf
# Piece 1 Edge 3 -> Dissimilarity: inf
# Piece 2 Edge 2 -> Dissimilarity: inf
# Piece 2 Edge 3 -> Dissimilarity: inf
# Piece 3 Edge 0 -> Dissimilarity: inf
# Piece 3 Edge 2 -> Dissimilarity: inf
# Piece 4 Edge 1 -> Dissimilarity: inf
# Piece 4 Edge 3 -> Dissimilarity: inf
# Piece 5 Edge 1 -> Dissimilarity: inf
# Piece 5 Edge 3 -> Dissimilarity: inf
# Piece 6 Edge 0 -> Dissimilarity: inf
# Piece 6 Edge 2 -> Dissimilarity: inf
# Piece 7 Edge 1 -> Dissimilarity: inf
# Piece 7 Edge 3 -> Dissimilarity: inf
# Piece 8 Edge 2 -> Dissimilarity: inf
# Piece 8 Edge 3 -> Dissimilarity: inf
# Piece 9 Edge 0 -> Dissimilarity: inf
# Piece 9 Edge 2 -> Dissimilarity: inf
# Piece 10 Edge 0 -> Dissimilarity: inf
# Piece 10 Edge 1 -> Dissimilarity: inf
# Piece 11 Edge 1 -> Dissimilarity: inf
# Piece 11 Edge 3 -> Dissimilarity: inf
# Piece 12 Edge 0 -> Dissimilarity: inf
# Piece 12 Edge 2 -> Dissimilarity: inf
# Piece 13 Edge 1 -> Dissimilarity: inf
# Piece 13 Edge 2 -> Dissimilarity: inf
# Piece 14 Edge 1 -> Dissimilarity: inf
# Piece 14 Edge 3 -> Dissimilarity: inf
# Piece 15 Edge 0 -> Dissimilarity: inf
# Piece 15 Edge 2 -> Dissimilarity: inf
# Piece 15 Edge 3 -> Dissimilarity: inf
# Piece 16 Edge 0 -> Dissimilarity: inf
# Piece 16 Edge 2 -> Dissimilarity: inf
# Piece 17 Edge 1 -> Dissimilarity: inf
# Piece 17 Edge 3 -> Dissimilarity: inf
# Piece 18 Edge 2 -> Dissimilarity: inf
# Piece 18 Edge 3 -> Dissimilarity: inf
# Piece 19 Edge 0 -> Dissimilarity: inf
# Piece 19 Edge 2 -> Dissimilarity: inf
# Piece 20 Edge 1 -> Dissimilarity: inf
# Piece 20 Edge 2 -> Dissimilarity: inf
# Piece 21 Edge 1 -> Dissimilarity: inf
# Piece 22 Edge 0 -> Dissimilarity: inf
# Piece 22 Edge 1 -> Dissimilarity: inf
# Piece 22 Edge 2 -> Dissimilarity: inf
# Piece 23 Edge 1 -> Dissimilarity: inf
# Piece 23 Edge 3 -> Dissimilarity: inf

# %%
edge_1 = Piece(8).edges[3]
edge_2 = Piece(24).edges[0]

edge_1.dissimilarity(edge_2, plot=True)
# Out:
# np.float64(3.6623659551981786)

# %%
edge_0_2.straighten_contour
# Out:
# array([[ 2.22020269e+02,  0.00000000e+00],
#        [ 2.19020543e+02, -4.05368394e-02],
#        [ 2.15980280e+02,  2.91865244e+00],
#        [ 2.14980372e+02,  2.90514016e+00],
#        [ 2.13966951e+02,  3.89153658e+00],
#        [ 2.05967681e+02,  3.78343834e+00],
#        [ 2.04981285e+02,  2.77001736e+00],
#        [ 2.02981467e+02,  2.74299280e+00],
#        [ 2.00954625e+02,  4.71578565e+00],
#        [ 1.80956451e+02,  4.44554005e+00],
#        [ 1.79943030e+02,  5.43193648e+00],
#        [ 1.74943487e+02,  5.36437508e+00],
#        [ 7.52363739e+01,  5.70218207e+01],
#        [ 7.42499775e+01,  5.60083998e+01],
#        [ 7.42634898e+01,  5.50084911e+01],
#        [ 7.32770933e+01,  5.39950701e+01],
#        [ 7.32906056e+01,  5.29951614e+01],
#        [ 7.23042092e+01,  5.19817404e+01],
#        [ 7.23447460e+01,  4.89820143e+01],
#        [ 7.33581670e+01,  4.79956178e+01],
#        [ 7.34257284e+01,  4.29960743e+01],
#        [ 7.44391494e+01,  4.20096779e+01],
#        [ 7.44661740e+01,  4.00098605e+01],
#        [ 7.85198579e+01,  3.60642748e+01],
#        [ 7.85874193e+01,  3.10647313e+01],
#        [ 7.96008403e+01,  3.00783348e+01],
#        [ 7.96143526e+01,  2.90784261e+01],
#        [ 8.06277735e+01,  2.80920297e+01],
#        [ 8.06412858e+01,  2.70921210e+01],
#        [ 8.16547068e+01,  2.61057246e+01],
#        [ 8.16817314e+01,  2.41059072e+01],
#        [ 8.37085733e+01,  2.21331143e+01],
#        [ 8.37896470e+01,  1.61336621e+01],
#        [ 7.78712685e+01,  1.00531362e+01],
#        [ 7.48715424e+01,  1.00125993e+01],
#        [ 7.28987495e+01,  7.98575736e+00],
#        [ 7.08989321e+01,  7.95873280e+00],
#        [ 6.99125357e+01,  6.94531182e+00],
#        [ 6.29131747e+01,  6.85072586e+00],
#        [ 6.19267783e+01,  5.83730487e+00],
#        [ 5.49274174e+01,  5.74271891e+00],
#        [ 5.29546245e+01,  3.71587694e+00],
#        [ 4.79550810e+01,  3.64831555e+00],
#        [ 4.69686846e+01,  2.63489456e+00],
#        [ 2.29708757e+01,  2.31059985e+00],
#        [ 2.19844792e+01,  1.29717886e+00],
#        [ 1.79848444e+01,  1.24312974e+00],
#        [ 1.69714234e+01,  2.22952617e+00],
#        [ 6.97233638e+00,  2.09440337e+00],
#        [ 5.98593995e+00,  1.08098238e+00],
#        [ 2.98621384e+00,  1.04044554e+00],
#        [ 1.99981741e+00,  2.70245596e-02],
#        [ 0.00000000e+00,  0.00000000e+00]])

# %%
import matplotlib.pyplot as plt
import cv2 as cv

# Plot all pieces; create/close a fresh figure per piece so Jupyter renders each one
for i in range(20):
    fig, axs = plt.subplots(2, 2, figsize=(6, 6))
    axs = axs.ravel()

    piece = Piece(i)
    img = cv.cvtColor(cv.imread(piece.back_img_path), cv.COLOR_BGR2RGB)

    for j in range(4):
        ax = axs[j]
        ax.clear()

        ax.imshow(img)

        contour = piece.edges[j].contour
        ax.plot(contour[:, 0], contour[:, 1], linewidth=1)

        c1, c2 = contour[0], contour[-1]
        ax.plot(c1[0], c1[1], "ro", markersize=3)
        ax.plot(c2[0], c2[1], "go", markersize=3)

        ax.set_title(f"Piece {i} / Edge {j} / {piece.edges[j].kind()}")
        ax.axis("off")

    fig.tight_layout()
    plt.show()
    plt.close(fig)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 25
#      22     ax.plot(c1[0], c1[1], "ro", markersize=3)
#      23     ax.plot(c2[0], c2[1], "go", markersize=3)
# ---> 25     ax.set_title(f"Piece {i} / Edge {j} / {piece.edges[j].kind()}")
#      26     ax.axis("off")
#      28 fig.tight_layout()
#
# TypeError: 'str' object is not callable
