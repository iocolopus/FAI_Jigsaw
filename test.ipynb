# %%
from jigsaw import Piece

# %%
piece = Piece(1)
piece.display_back()

# %%
piece.display_back()

# %%
piece = Piece(0)
num = 2
piece.edges[num].plot()
piece = Piece(5)
num = 0
piece.edges[num].plot()

# %%
piece_0_2 = Piece(0)
piece_5_0 = Piece(5)

edge_0_2 = piece_0_2.edges[2]
edge_5_0 = piece_5_0.edges[0]

# %%
edge_0_2.straighten_contour
# Out:
# array([[ 2.21002262e+02, -1.11022302e-16],
#        [ 2.17002303e+02, -1.80993622e-02],
#        [ 2.15997789e+02,  9.77365560e-01],
#        [ 2.14997799e+02,  9.72840720e-01],
#        [ 2.13993284e+02,  1.96830564e+00],
#        [ 2.05993366e+02,  1.93210692e+00],
#        [ 2.04997901e+02,  9.27592314e-01],
#        [ 2.02997922e+02,  9.18542633e-01],
#        [ 2.00988893e+02,  2.90947248e+00],
#        [ 1.80989097e+02,  2.81897567e+00],
#        [ 1.79984583e+02,  3.81444059e+00],
#        [ 1.74984634e+02,  3.79181639e+00],
#        [ 1.72975605e+02,  5.78274623e+00],
#        [ 1.50975830e+02,  5.68319974e+00],
#        [ 1.49980365e+02,  4.67868513e+00],
#        [ 1.39980467e+02,  4.63343673e+00],
#        [ 1.38975953e+02,  5.62890165e+00],
#        [ 1.32976014e+02,  5.60175261e+00],
#        [ 1.31971500e+02,  6.59721753e+00],
#        [ 1.30971510e+02,  6.59269269e+00],
#        [ 1.29966995e+02,  7.58815761e+00],
#        [ 1.28967006e+02,  7.58363277e+00],
#        [ 1.27962491e+02,  8.57909769e+00],
#        [ 1.26962501e+02,  8.57457285e+00],
#        [ 1.25957987e+02,  9.57003778e+00],
#        [ 1.24957997e+02,  9.56551294e+00],
#        [ 1.19935424e+02,  1.45428375e+01],
#        [ 1.19899225e+02,  2.25427556e+01],
#        [ 1.20894690e+02,  2.35472703e+01],
#        [ 1.20885640e+02,  2.55472498e+01],
#        [ 1.21881105e+02,  2.65517644e+01],
#        [ 1.21872056e+02,  2.85517439e+01],
#        [ 1.22867520e+02,  2.95562585e+01],
#        [ 1.22862996e+02,  3.05562483e+01],
#        [ 1.23858461e+02,  3.15607629e+01],
#        [ 1.23853936e+02,  3.25607526e+01],
#        [ 1.25844866e+02,  3.45697818e+01],
#        [ 1.25840341e+02,  3.55697716e+01],
#        [ 1.26835806e+02,  3.65742862e+01],
#        [ 1.26826756e+02,  3.85742657e+01],
#        [ 1.27822221e+02,  3.95787803e+01],
#        [ 1.27817696e+02,  4.05787701e+01],
#        [ 1.28813161e+02,  4.15832847e+01],
#        [ 1.28808636e+02,  4.25832745e+01],
#        [ 1.29804101e+02,  4.35877891e+01],
#        [ 1.29776952e+02,  4.95877277e+01],
#        [ 1.28772437e+02,  5.05831926e+01],
#        [ 1.28754338e+02,  5.45831516e+01],
#        [ 1.27754348e+02,  5.45786268e+01],
#        [ 1.25745319e+02,  5.65695566e+01],
#        [ 1.25736269e+02,  5.85695362e+01],
#        [ 1.24740804e+02,  5.75650216e+01],
#        [ 1.23736290e+02,  5.85604865e+01],
#        [ 1.23731765e+02,  5.95604762e+01],
#        [ 1.22727250e+02,  6.05559412e+01],
#        [ 1.22722726e+02,  6.15559309e+01],
# (array([220.02044678, 213.41675019, 207.55683325, 200.2964053 ,
#         193.43651562, 186.17608906, 178.91566251, 172.03544626,
#         164.79534474, 157.534916  , 151.06747642, 143.88325351,
#         136.98252085, 129.72209532, 123.73994894, 118.95586527,
#         115.80211518, 117.71422415, 120.0438106 , 122.97459559,
#         122.46756741, 123.3741221 , 120.9425138 , 115.54617011,
#         109.96825876, 103.63145249,  96.73906821,  89.73605929,
#          82.90344658,  76.70728104,  71.34088564,  68.33771538,
#          67.43116322,  70.34670964,  74.14451312,  77.23926856,
#          78.76403976,  78.51164233,  73.24076779,  66.83596222,
#          60.29490439,  53.59854493,  46.33811761,  39.07769028,
#          32.15140639,  24.95737741,  18.1247616 ,  11.26487515,
#           7.26042701,   0.        ]),
#  array([-1.31006317e-14,  3.11143167e-01,  8.30134506e-01,  7.31128651e-01,
#          1.63767778e+00,  1.53867191e+00,  1.43966603e+00,  2.29518342e+00,
#          2.24720923e+00,  2.14820332e+00,  2.14266818e+00,  2.06403645e+00,
#          2.86803654e+00,  2.76903069e+00,  5.87914137e+00,  1.05345047e+01,
#          1.53022047e+01,  2.17615488e+01,  2.80545966e+01,  3.41081704e+01,
#          3.98834160e+01,  4.67433014e+01,  5.30000561e+01,  5.75808359e+01,
#          6.17057663e+01,  6.39255141e+01,  6.39267097e+01,  6.32294378e+01,
#          6.21361739e+01,  5.95637568e+01,  5.50628982e+01,  4.90381512e+01,
#          4.21782648e+01,  3.61297433e+01,  3.04608419e+01,  2.44894336e+01,
#          1.78425010e+01,  1.07220483e+01,  5.99920277e+00,  3.91167836e+00,
#          2.14081624e+00,  7.30889218e-01,  6.31883402e-01,  5.32877585e-01,
#          1.27273507e+00,  1.34042084e+00,  2.47155827e-01,  1.15370486e+00,
#          9.90058262e-02,  0.00000000e+00]))

# %%
edge_0_2.dissimilarity(edge_5_0, plot=True)
# Out:
# np.float64(2.879619452472251)

# %%
import numpy as np
from itertools import product

c1 = 0  # Coeficiente para la diferencia de longitudes
n_samples = 30  # Número de muestras para el remuestreo

test_edge = Piece(0).edges[2]

def disimilarity_tests(i_piece, i_edge, c1=c1, n_samples=n_samples):
    piece = Piece(i_piece)
    edge = piece.edges[i_edge]
    return test_edge.dissimilarity(edge, c1=c1, n_samples=n_samples, plot=False)

# Generar todas las combinaciones (pieza, arista)
piece_edge_combinations = list(product(range(25), range(4)))

# Ordenar por dissimilarity (de menor a mayor)
piece_edge_combinations_sorted = sorted(
    piece_edge_combinations, 
    key=lambda x: disimilarity_tests(x[0], x[1], c1=c1, n_samples=n_samples)
)

for i_piece, i_edge in piece_edge_combinations_sorted:
    disim = disimilarity_tests(i_piece, i_edge, c1=c1, n_samples=n_samples)
    print(f"Piece {i_piece} Edge {i_edge} -> Dissimilarity: {disim}")
# Out:
# Piece 5 Edge 0 -> Dissimilarity: 2.8159015919191708
# Piece 17 Edge 2 -> Dissimilarity: 4.04053427117048
# Piece 24 Edge 2 -> Dissimilarity: 6.5345014921908975
# Piece 19 Edge 3 -> Dissimilarity: 6.737984732107746
# Piece 2 Edge 0 -> Dissimilarity: 7.442862435884723
# Piece 17 Edge 0 -> Dissimilarity: 8.100109988514252
# Piece 6 Edge 3 -> Dissimilarity: 8.14279520884406
# Piece 9 Edge 3 -> Dissimilarity: 8.36299757803969
# Piece 13 Edge 0 -> Dissimilarity: 8.67384396302574
# Piece 16 Edge 3 -> Dissimilarity: 8.735454194120614
# Piece 19 Edge 1 -> Dissimilarity: 9.229355032747474
# Piece 8 Edge 0 -> Dissimilarity: 9.503048856750407
# Piece 1 Edge 0 -> Dissimilarity: 9.546243763279602
# Piece 12 Edge 1 -> Dissimilarity: 9.920444233832374
# Piece 21 Edge 2 -> Dissimilarity: 10.147868096065446
# Piece 18 Edge 0 -> Dissimilarity: 10.422742741800894
# Piece 23 Edge 0 -> Dissimilarity: 10.440956466776742
# Piece 0 Edge 3 -> Dissimilarity: 10.513425110628534
# Piece 1 Edge 2 -> Dissimilarity: 10.571052568162374
# Piece 21 Edge 3 -> Dissimilarity: 10.616040132831058
# Piece 16 Edge 1 -> Dissimilarity: 10.624464632350014
# Piece 7 Edge 2 -> Dissimilarity: 10.851708434414755
# Piece 21 Edge 0 -> Dissimilarity: 11.082720618940366
# Piece 9 Edge 1 -> Dissimilarity: 11.162803120023097
# Piece 11 Edge 0 -> Dissimilarity: 11.228976057156544
# Piece 5 Edge 2 -> Dissimilarity: 11.319552845876801
# Piece 4 Edge 0 -> Dissimilarity: 11.579495475858284
# Piece 22 Edge 3 -> Dissimilarity: 11.642162061414693
# Piece 24 Edge 0 -> Dissimilarity: 11.723602206153195
# Piece 11 Edge 2 -> Dissimilarity: 11.772331934677817
# Piece 13 Edge 3 -> Dissimilarity: 12.259544993481835
# Piece 3 Edge 3 -> Dissimilarity: 12.367430780032283
# Piece 24 Edge 1 -> Dissimilarity: 12.79121508162376
# Piece 12 Edge 3 -> Dissimilarity: 13.36375460951195
# Piece 6 Edge 1 -> Dissimilarity: 14.204743113832354
# Piece 10 Edge 2 -> Dissimilarity: 14.298162170860559
# Piece 20 Edge 3 -> Dissimilarity: 14.318333176468562
# Piece 4 Edge 2 -> Dissimilarity: 14.37275880621727
# Piece 18 Edge 1 -> Dissimilarity: 14.573885151118867
# Piece 7 Edge 0 -> Dissimilarity: 15.586697074900146
# Piece 3 Edge 1 -> Dissimilarity: 15.599476416609132
# Piece 23 Edge 2 -> Dissimilarity: 15.831975431534648
# Piece 0 Edge 1 -> Dissimilarity: 17.21514202598563
# Piece 10 Edge 3 -> Dissimilarity: 18.25128114591184
# Piece 15 Edge 1 -> Dissimilarity: 18.734807208390922
# Piece 14 Edge 0 -> Dissimilarity: 19.321841656122455
# Piece 2 Edge 1 -> Dissimilarity: 19.688862539563747
# Piece 20 Edge 0 -> Dissimilarity: 21.470331908604805
# Piece 24 Edge 3 -> Dissimilarity: 22.49804421295786
# Piece 8 Edge 1 -> Dissimilarity: 24.192612953645032
# Piece 14 Edge 2 -> Dissimilarity: 24.440800067383947
# Piece 0 Edge 0 -> Dissimilarity: inf
# Piece 0 Edge 2 -> Dissimilarity: inf
# Piece 1 Edge 1 -> Dissimilarity: inf
# Piece 1 Edge 3 -> Dissimilarity: inf
# Piece 2 Edge 2 -> Dissimilarity: inf
# Piece 2 Edge 3 -> Dissimilarity: inf
# Piece 3 Edge 0 -> Dissimilarity: inf
# Piece 3 Edge 2 -> Dissimilarity: inf
# Piece 4 Edge 1 -> Dissimilarity: inf
# Piece 4 Edge 3 -> Dissimilarity: inf
# Piece 5 Edge 1 -> Dissimilarity: inf
# Piece 5 Edge 3 -> Dissimilarity: inf
# Piece 6 Edge 0 -> Dissimilarity: inf
# Piece 6 Edge 2 -> Dissimilarity: inf
# Piece 7 Edge 1 -> Dissimilarity: inf
# Piece 7 Edge 3 -> Dissimilarity: inf
# Piece 8 Edge 2 -> Dissimilarity: inf
# Piece 8 Edge 3 -> Dissimilarity: inf
# Piece 9 Edge 0 -> Dissimilarity: inf
# Piece 9 Edge 2 -> Dissimilarity: inf
# Piece 10 Edge 0 -> Dissimilarity: inf
# Piece 10 Edge 1 -> Dissimilarity: inf
# Piece 11 Edge 1 -> Dissimilarity: inf
# Piece 11 Edge 3 -> Dissimilarity: inf
# Piece 12 Edge 0 -> Dissimilarity: inf
# Piece 12 Edge 2 -> Dissimilarity: inf
# Piece 13 Edge 1 -> Dissimilarity: inf
# Piece 13 Edge 2 -> Dissimilarity: inf
# Piece 14 Edge 1 -> Dissimilarity: inf
# Piece 14 Edge 3 -> Dissimilarity: inf
# Piece 15 Edge 0 -> Dissimilarity: inf
# Piece 15 Edge 2 -> Dissimilarity: inf
# Piece 15 Edge 3 -> Dissimilarity: inf
# Piece 16 Edge 0 -> Dissimilarity: inf
# Piece 16 Edge 2 -> Dissimilarity: inf
# Piece 17 Edge 1 -> Dissimilarity: inf
# Piece 17 Edge 3 -> Dissimilarity: inf
# Piece 18 Edge 2 -> Dissimilarity: inf
# Piece 18 Edge 3 -> Dissimilarity: inf
# Piece 19 Edge 0 -> Dissimilarity: inf
# Piece 19 Edge 2 -> Dissimilarity: inf
# Piece 20 Edge 1 -> Dissimilarity: inf
# Piece 20 Edge 2 -> Dissimilarity: inf
# Piece 21 Edge 1 -> Dissimilarity: inf
# Piece 22 Edge 0 -> Dissimilarity: inf
# Piece 22 Edge 1 -> Dissimilarity: inf
# Piece 22 Edge 2 -> Dissimilarity: inf
# Piece 23 Edge 1 -> Dissimilarity: inf
# Piece 23 Edge 3 -> Dissimilarity: inf

# %%
edge_1 = Piece(23).edges[3]
edge_2 = Piece(24).edges[1]
#edge_2 = Piece(4).edges[2]

edge_1.dissimilarity(edge_2, plot=True)
# Out:
# np.float64(5.062233309584638)

# %%
edge_1 = Piece(23).edges[3]
#edge_2 = Piece(24).edges[1]
edge_2 = Piece(4).edges[2]

edge_1.dissimilarity(edge_2, plot=True)
# Out:
# np.float64(4.606382059944011)

# %%
edge_0_2.straighten_contour
# Out:
# array([[ 2.21002262e+02, -1.11022302e-16],
#        [ 2.17002303e+02, -1.80993622e-02],
#        [ 2.15997789e+02,  9.77365560e-01],
#        [ 2.14997799e+02,  9.72840720e-01],
#        [ 2.13993284e+02,  1.96830564e+00],
#        [ 2.05993366e+02,  1.93210692e+00],
#        [ 2.04997901e+02,  9.27592314e-01],
#        [ 2.02997922e+02,  9.18542633e-01],
#        [ 2.00988893e+02,  2.90947248e+00],
#        [ 1.80989097e+02,  2.81897567e+00],
#        [ 7.57413061e+01,  5.73433044e+01],
#        [ 7.57458309e+01,  5.63433146e+01],
#        [ 7.47503660e+01,  5.53388000e+01],
#        [ 7.47548908e+01,  5.43388102e+01],
#        [ 7.37594259e+01,  5.33342956e+01],
#        [ 7.37639507e+01,  5.23343059e+01],
#        [ 7.27684858e+01,  5.13297913e+01],
#        [ 7.27820603e+01,  4.83298220e+01],
#        [ 7.37865749e+01,  4.73343571e+01],
#        [ 7.38091991e+01,  4.23344082e+01],
#        [ 7.48137138e+01,  4.13389433e+01],
#        [ 7.48227634e+01,  3.93389638e+01],
#        [ 7.88408218e+01,  3.53571041e+01],
#        [ 7.88634460e+01,  3.03571553e+01],
#        [ 7.98679607e+01,  2.93616904e+01],
#        [ 7.98724855e+01,  2.83617006e+01],
#        [ 8.08770001e+01,  2.73662357e+01],
#        [ 8.08815249e+01,  2.63662459e+01],
#        [ 8.18860395e+01,  2.53707810e+01],
#        [ 8.18950892e+01,  2.33708015e+01],
#        [ 8.39041184e+01,  2.13798716e+01],
#        [ 8.39312675e+01,  1.53799330e+01],
#        [ 7.79584779e+01,  9.35284543e+00],
#        [ 7.49585086e+01,  9.33927091e+00],
#        [ 7.29675788e+01,  7.33024170e+00],
#        [ 7.09675993e+01,  7.32119202e+00],
#        [ 6.99721344e+01,  6.31667742e+00],
#        [ 6.29722060e+01,  6.28500353e+00],
#        [ 6.19767411e+01,  5.28048893e+00],
#        [ 5.49768128e+01,  5.24881504e+00],
#        [ 5.29858829e+01,  3.23978584e+00],
#        [ 4.79859341e+01,  3.21716164e+00],
#        [ 4.69904692e+01,  2.21264703e+00],
#        [ 2.29907149e+01,  2.10405086e+00],
#        [ 2.19952499e+01,  1.09953626e+00],
#        [ 1.79952909e+01,  1.08143689e+00],
#        [ 1.69907763e+01,  2.07690182e+00],
#        [ 6.99087866e+00,  2.03165341e+00],
#        [ 5.99541374e+00,  1.02713881e+00],
#        [ 2.99544445e+00,  1.01356428e+00],
#        [ 1.99997953e+00,  9.04968111e-03],
#        [ 0.00000000e+00,  0.00000000e+00]])

# %%
import matplotlib.pyplot as plt
import cv2 as cv

# Plot all pieces; create/close a fresh figure per piece so Jupyter renders each one
for i in range(20):
    fig, axs = plt.subplots(2, 2, figsize=(6, 6))
    axs = axs.ravel()

    piece = Piece(i)
    img = cv.cvtColor(cv.imread(piece.back_img_path), cv.COLOR_BGR2RGB)

    for j in range(4):
        ax = axs[j]
        ax.clear()

        ax.imshow(img)

        contour = piece.edges[j].contour
        ax.plot(contour[:, 0], contour[:, 1], linewidth=1)

        c1, c2 = contour[0], contour[-1]
        ax.plot(c1[0], c1[1], "ro", markersize=3)
        ax.plot(c2[0], c2[1], "go", markersize=3)

        ax.set_title(f"Piece {i} / Edge {j} / {piece.edges[j].kind()}")
        ax.axis("off")

    fig.tight_layout()
    plt.show()
    plt.close(fig)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 25
#      22     ax.plot(c1[0], c1[1], "ro", markersize=3)
#      23     ax.plot(c2[0], c2[1], "go", markersize=3)
# ---> 25     ax.set_title(f"Piece {i} / Edge {j} / {piece.edges[j].kind()}")
#      26     ax.axis("off")
#      28 fig.tight_layout()
#
# TypeError: 'str' object is not callable
