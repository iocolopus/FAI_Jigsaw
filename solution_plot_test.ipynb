# %%
from jigsaw import *

# %%
solver = Backtrack_solver([Piece(i) for i in range(25)])
solver.solve()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 2
#       1 solver = Backtrack_solver([Piece(i) for i in range(25)])
# ----> 2 solver.solve()
#
# File c:\Users\iocol\Desktop\FAI_Jigsaw\jigsaw.py:563, in Backtrack_solver.solve(self)
#     554         return current_solution
#     556     return None
# --> 563 return r_solve(start_solution)
#
# File c:\Users\iocol\Desktop\FAI_Jigsaw\jigsaw.py:381, in Backtrack_solver.solve.<locals>.r_solve(current_solution)
#     373 dif = (next_i - spiral_index[len(current_solution)-1][0], next_j - spiral_index[len(current_solution)-1][1])
#     374 mapping_dif_to_edge_id = {
#     375     (0, 1): (1, 3),   # ir derecha
#     376     (1, 0): (2, 0),   # ir abajo: arista abajo(2) de anterior, arriba(0) de nueva
#     377     (0, -1): (3, 1),  # ir izquierda
# ...
